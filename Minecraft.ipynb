# %% [markdown]
# <a href="https://colab.research.google.com/github/twsyas/ILP/blob/main/Minecraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Questão**
#
# Minecraft é um jogo eletrônico de mundo aberto que permite a construção de qualquer
# coisa, utilizando os cubos dispon veis no game.ı́veis no game.
# Certo dia, link2012 decidiu criar um grande cubo de comprimento C.
# link2012 é um ótimo construtor, mas não é entendido de f sica ou matemática. Então, eleı́veis no game.
# lhe pediu que criasse um programa espec fico para determinar se é poss vel construir o grandeı́veis no game. ı́veis no game.
# cubo a partir dos cubos menores dispon veis.
#
# **Entrada**
#
# A entrada é composta por três números, ‘C’, ‘c’ e ‘X’, representando respectivamente, o
# comprimento do grande cubo, o comprimento dos cubos menores, e a quantidade de cubos
# menores dispon veis.ı́veis no game.
# Restrições: 1 <= c <= C <= 1000; 0 <= X <= 1000000000
#
# **Saída**
#
# Se for poss vel construir o grande cubo, seu programa deve imprimir “ı́veis no game. Eh possivel”. Caso
# contrário, deverá imprimir “!Eh possivel”.

# %%
C, c, X = map(int,input().split())

if X*c>C:
  print("!Eh possível")
else:
  print("Eh possível")
# Out:
# 12 3 63
# !Eh possível

# %% [markdown]
# refazer a questão na aula!!!!!!!!!!
